# %% [markdown]
# # Lab Assignment 11: Data Visualizations
# ## DS 6001
#
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.

# %% [markdown]
# ## Problem 0
# Load the Conda environment you originally built back in module 1 as the kernel of this notebook, and import the following packages:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Problem 1
# One of the great joys of learning about data visualizations is seeing truly terrible data visualizations and describing just what it is about the visualization that makes it so awful.

# %% [markdown]
# ### Part a
# Critique the following data visualization by writing a paragraph in your own words. Pay particular attention to how the figure communicates information to a general audience and tells a story that is incomplete or misleading. Make specific references to the ideas presented in [section 11.1 of the textbook](https://jkropko.github.io/surfing-the-data-pipeline/ch11.html#introduction-what-makes-for-a-good-data-visualization).
#
# <img src="https://i.redd.it/eggale9wy8sd1.jpeg" width='500'>
#
# [4 points]

# %% [markdown]
# <strong>
# In this image, the two trianges next to each other are the same size and positioned in such a way that they appear to be in relation: in comparison, in contrast, something. It isn't exactly clear what relationship is being telegraphed, but it is clear there is something. However, these two pieces of information, at a basic level, cannot be compared, because as we see when we read the captions, one is "Since Jan '21", and one is "Since Last Sept.". They are not on at all the same timeline, so positioning them in relation is misleading. Additionally, the two trianges are the same size, but the values they represent are very different. If the story they are trying to tell is that grocery prices have increased far more than avg. hourly wages, it would be more effective to show that difference using the shapes. As it is, the only thing I get from this comparison visually is the vague impression of an up arrow and therefore the sense that both have increased.
# </strong>

# %% [markdown]
# ### Part b
# Critique the following data visualization by writing a paragraph in your own words. Pay particular attention to how the figure communicates information to a general audience and tells a story that is incomplete or misleading. Make specific references to the ideas presented in [section 11.1 of the textbook](https://jkropko.github.io/surfing-the-data-pipeline/ch11.html#introduction-what-makes-for-a-good-data-visualization).
#
# <img src="https://www.designyourway.net/diverse/2/wronginfo/59426786926.jpg" width='600'>
#
# [4 points]

# %% [markdown]
# <strong>
# I honestly can't really even figure out what is going on here. I think its a bar plot wher they're also varying the radii of the wedges to show larger or smaller data. Additionally, it's three dimensional. Between both of these modidifications, the visualization certainly violates the principle of proportional ink. The value associated with "Production" is 7.2%, and the value for "Information and Communication" is 13.4%. I&C is less than twice the value of Production, but visually it is much more than twice the size.
#
# Additionally, in terms of the story told by the image, the most dominant part of the visual is the "Other" portion, which tells me nothing. What it tells me more than anything is that this chart really tells nothing because we're missing over one fourth of the information.
#
# Lastly, I'm confused by what data the visual is even showing. Birth rate is births per population. Because this is expressed as a pie chart with percents, that does not make sense.I assume it is showing what % of births in some timeline are from people within some sector, but that is not made clear in the visualization's title.
# </strong>

# %% [markdown]
# ### Part c
# Critique the following data visualization by writing a paragraph in your own words. Pay particular attention to how the figure communicates information to a general audience and tells a story that is incomplete or misleading. Make specific references to the ideas presented in [section 11.1 of the textbook](https://jkropko.github.io/surfing-the-data-pipeline/ch11.html#introduction-what-makes-for-a-good-data-visualization).
#
# <img src="https://i.imgur.com/sTVYOIH.jpg" width='400'>
#
# [4 points]

# %% [markdown]
# <strong>
#
# Because the axis has zero at the top, even though the shaded area is the relevant area, it look like the murder by firearm numbers changed in the opposite direction they actually changed. For example, murders by firearms spiked after Florida's "Stand Your Ground" law, but this visualization strongly implies at first look that murder rates *declined*. Relatedly, this visualization makes it look like murder by firearm rates were increasing until the introduction of this law, when the opposite is true. There is absolutely no reason to have the y-axis go down like that instead of up, other than to obscure the story.
# </strong>

# %% [markdown]
# ### Part d
# Lots of data scientists pursue the hobby of finding, posting, and ripping into bad data visualizations when they find them. The most active forum for this hobby is Reddit's [/r/dataisugly](https://www.reddit.com/r/dataisugly/) board. Take a look at this page and choose one visualization (note that you can sort the posts by new, top, best, etc.). Right click on the image and select "Copy Image Address" or "Copy Image Link", then you can display it in your notebook by pasting the URL into the src attribute of an HTML img tag. For example:
# ```
# <img src="https://i.imgur.com/sTVYOIH.jpg" width='400'>
# ```
#
# For this image, answer (in your own words) two questions:
#
# 1. What makes this visualization such a bad one?
#
# 2. Find and describe something good or redeemable about the image.
#
# For both questions, make a specific reference to concepts discussed [section 11.1 of the textbook](https://jkropko.github.io/surfing-the-data-pipeline/ch11.html#introduction-what-makes-for-a-good-data-visualization).
#
# (Note: if you cannot get the image to display in your notebook or in your PDF, just supply the link. Please don't spend a lot of time on image display issues.)
#
# [4 points]

# %% [markdown]
# <img src="https://preview.redd.it/why-does-the-red-line-go-back-so-far-v0-hllcj7aidc0g1.jpeg?width=1080&crop=smart&auto=webp&s=e3d3304a53502bd6485b03381cbdff975e7f7059" width='400'>

# %% [markdown]
# <strong>
# First, I'll talk about the good things. The visual has axes with clearly labeled values that start from an appropriate place. Additionally, data is easy to see. The colors are clear and distinct. In some ways, the story they're trying to tell is very clear. the values since January 2025 have gotten much much larger.
#
# Now, let's discuss the negatives. First, nothing is well labeled. There is no legend, there are no axis labels. The choice to use April and October is a strange one to me, a lay person. It makes it vaguely look like Trump became president in October 2024. Also, hilariously, the fact that there is so much more ink dedicated to Biden's bars than Trump's line makes Trump's increased tariff revenue *less* "impressive". Staying on the line for a second, why does it continue all the way back to January 2021. If I were a conspiracy theorist, or just a person who knows what Fox news says, I might say it's sending the subliminal message that Trump was the shadow president for the 4 years Biden was in office. Anyway, jokes (not jokes) aside, the coninuation of that line (which should never have existed as a line in the first place) back to 2021 makes no sense.
#
# The obvious serious problems in this chart aside (and the fact that due to the chart's source, I don't trust the integrity of the data), I think this chart could benefit from a bit more storytelling. This could use an indication of what Trump did that improved tariff revenue so much. The Florida firearms murders chart was terrible, but one thing it did well was draw attention to a key datapoint and give an explanation for it. There is so much free whitespace because of the massive increase in tariff revenue under Trump that it's an opportunity to improve the story with a little annotating.
# </strong>

# %% [markdown]
# ### Part e
# The flipside of the /r/dataisugly board is the [/r/dataisbeautiful](https://www.reddit.com/r/dataisbeautiful/) board, where users post data visualizations that they find to be especially high quality or visually appealing. (That said, whenever I look at this /r/dataisbeautiful I see visualizations that I would never call beautiful.)
#
# Take a look at this page and choose one visualization (note that you can sort the posts by new, top, best, etc.). Right click on the image and select "Copy Image Address"/"Copy Image Link", then you can display it in your notebook by pasting the URL into the src attribute of an HTML img tag.
#
# For this image, answer (in your own words) two questions:
#
# 1. What makes this visualization such a good one?
#
# 2. Find and describe something that is lacking, misleading, or confusing about the visualization.
#
# For both questions, make a specific reference to concepts discussed [section 11.1 of the textbook](https://jkropko.github.io/surfing-the-data-pipeline/ch11.html#introduction-what-makes-for-a-good-data-visualization).
#
# (Note: if you cannot get the image to display in your notebook or in your PDF, just supply the link. Please don't spend a lot of time on image display issues.)
#
# [4 points]

# %% [markdown]
# <img src="https://preview.redd.it/government-shutdowns-in-the-u-s-v0-717hbtwva9yf1.png?width=1080&crop=smart&auto=webp&s=cfdb79d2384272a03a28488d26f5992652c54732" width='400'>

# %% [markdown]
# <strong>
# I like this chart because while it is simple, it packs in a lot of information and tells a clear story. The scale of days is very clear and starts at 0. I can imagine it might have been tempting to show more about the lengths of time between each of these shut downs, and while that would be interesting, that is not what this visualization is trying to tell us. Additionally, I find the addition of the information about the parties in power in various parts of government well-integrated into the chart. It does not visually distract and it tells a clear story as well. I can look at this graph and gather a few quick takeaways:
#
# - Trump's recent government shutdowns are the longest in recent history.
# - While government shut downs happened pretty evently under Democrats and Republicans in the eighties, since then republicans have held more power for many of the shut downs since.
# - Yes, Trump and Reagan both had three shut downs, but Reagan's were far far shorter.
#
# Areas for improvement:
# - The title makes it sound like the graph describes the number of shut downs, not the length. I had to read the subheader and the x-axis to understand what I was seeing.
# - There are a lot of gridlines here that are unnecessary. The 5 day lines are sufficient, and I think they should be in a different color from the horizontal lines for each bar, because one represents categorical data and one represents quantitative data.
# - This is nit-picky, but pink/blue is a very gendered color pairing in American culture. While I don't think that color combo should be used for gender-breakdowns, I think it should also be avoided for other data as it could be misleading.
# </strong>

# %% [markdown]
# ## Problem 2
# For the rest of this lab, we will once again be working with the 2018 General Social Survey.

# %%
gss = pd.read_csv("https://github.com/jkropko/DS-6001/raw/master/localdata/gss2018.csv",
                 encoding='cp1252', na_values=['IAP','IAP,DK,NA,uncodeable', 'NOT SURE',
                                               'DK', 'IAP, DK, NA, uncodeable', 
                                               '.a', "CAN'T CHOOSE"],
                                               low_memory=False)

# %% [markdown]
# Here is code that cleans the data and gets it ready to be used for data visualizations:

# %%
mycols = ['id', 'wtss', 'sex', 'educ', 'region', 'age', 'coninc',
          'prestg10', 'mapres10', 'papres10', 'sei10', 'satjob',
          'fechld', 'fefam', 'fepol', 'fepresch', 'meovrwrk'] 
gss_clean = gss[mycols]
gss_clean = gss_clean.rename({'wtss':'weight', 
                              'educ':'education', 
                              'coninc':'income', 
                              'prestg10':'job_prestige',
                              'mapres10':'mother_job_prestige', 
                              'papres10':'father_job_prestige', 
                              'sei10':'socioeconomic_index', 
                              'fechld':'relationship', 
                              'fefam':'male_breadwinner', 
                              'fehire':'hire_women', 
                              'fejobaff':'preference_hire_women', 
                              'fepol':'men_bettersuited', 
                              'fepresch':'child_suffer',
                              'meovrwrk':'men_overwork'},axis=1)
gss_clean.age = gss_clean.age.replace({'89 or older':'89'})
gss_clean.age = gss_clean.age.astype('float')

# %% [markdown]
# The `gss_clean` dataframe now contains the following features:
#
# * `id` - a numeric unique ID for each person who responded to the survey
# * `weight` - survey sample weights
# * `sex` - male or female
# * `education` - years of formal education
# * `region` - region of the country where the respondent lives
# * `age` - age
# * `income` - the respondent's personal annual income
# * `job_prestige` - the respondent's occupational prestige score, as measured by the GSS using the methodology described above
# * `mother_job_prestige` - the respondent's mother's occupational prestige score, as measured by the GSS using the methodology described above
# * `father_job_prestige` -the respondent's father's occupational prestige score, as measured by the GSS using the methodology described above
# * `socioeconomic_index` - an index measuring the respondent's socioeconomic status
# * `satjob` - responses to "On the whole, how satisfied are you with the work you do?"
# * `relationship` - agree or disagree with: "A working mother can establish just as warm and secure a relationship with her children as a mother who does not work."
# * `male_breadwinner` - agree or disagree with: "It is much better for everyone involved if the man is the achiever outside the home and the woman takes care of the home and family."
# * `men_bettersuited` - agree or disagree with: "Most men are better suited emotionally for politics than are most women."
# * `child_suffer` - agree or disagree with: "A preschool child is likely to suffer if his or her mother works."
# * `men_overwork` - agree or disagree with: "Family life often suffers because men concentrate too much on their work."

# %% [markdown]
# ### Part a
# Reorder the categories of `relationship` to "strongly agree", "agree", "disagree", and "strongly disagree".
#
# Then create a simple barplot that shows the frequencies of the categories of `relationship`. Make sure the barplot has descriptive axis labels and a title, and set a good size for each figure displayed in the Jupyter notebook. You may use any of the following packages/methods for generating this plot:
#
# * `matplotlib`,
# * `seaborn`
# * or the `.plot()` method from `pandas`
#
# Answers that use a different package will not receive credit. (These packages are still the workhorse tools for static data visualization in Python, and it's important to know them as these will most likely be big parts of the visualization toolkit you will use in a workplace setting.)
#
# [8 points]

# %%
agree_disagree_order = [
    'strongly agree',
    'agree',
    'disagree',
    'strongly disagree'
]
gss_clean.relationship = gss_clean.relationship.astype('category')
gss_clean.relationship =gss_clean.relationship.cat.reorder_categories(agree_disagree_order)

bars = gss_clean.relationship.value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.barplot(x=bars.index, y=bars.values) 
plt.title('\nStatement:\n "A working mother can establish just as warm and secure a relationship \n \
          with her children as a mother who does not work."\n',
          fontsize=14)
plt.xlabel('Response')
plt.ylabel('Count of Responses')
# Out:
# Text(0, 0.5, 'Count of Responses')

# %% [markdown]
# ### Part b
# Create a barplot that shows
# * the frequency of the different levels of agreement for `relationship` for men and for women on the same plot,
# * with bars for men and bars for women side-by-side,
# * using different colors for the bars for men and the bars for women,
# * listing these colors and the sex they refer to in a legend,
# * and labeling each bar with the number the bar represents.
#
# Use `seaborn`, `matplotlib`, and the `.plot()` method for a pandas dataframe as you see fit.
#
# [8 points]

# %%
bars = gss_clean[['relationship', 'sex']].value_counts().reset_index()
plt.figure(figsize=(10, 6))
relationship_sex = sns.barplot(x='relationship', y='count', hue='sex', data=bars)
plt.title('\nStatement:\n "A working mother can establish just as warm and secure a relationship \n \
          with her children as a mother who does not work."\n',
          fontsize=14)
plt.xlabel('Response')
plt.ylabel('Count of Responses')

for rect in relationship_sex.patches:
    xcoor = rect.get_x() + .5*rect.get_width()
    if (xcoor != 0):
        # there are 2 extra patches at the start and end of the plot, want to not include those
        ycoor = rect.get_height()
        plt.text(xcoor, ycoor - 25, str(int(ycoor)), 
                horizontalalignment='center', 
                verticalalignment='bottom',
                fontsize=14)

# %% [markdown]
# ### Part c
# Create a visualization with
# * nine barplots, arranged in a 3x3 grid.
# * The barplots should refer to each of the nine categories of `region`,
# * and each barplot should be given a label that contains the name of the region.
# * Within each barplot, list the categories of `relationship`,
# * and display horizontal bars.
#
# Use `seaborn`, `matplotlib`, and the `.plot()` method of a pandas dataframe as you see fit.
#
# [10 points]

# %%
partc_data = gss_clean[['region', 'relationship']].value_counts().reset_index()
partc_data
fg = sns.FacetGrid(partc_data, col = 'region', col_wrap=3)
fg.map(sns.barplot, 'count', 'relationship', order=agree_disagree_order, errorbar=None)
fg.set_titles('{col_name}')

# %% [markdown]
# ## Problem 3
# Write code that exactly replicates the following figures, including all aesthetic choices. **Don't worry, however, about making the size of the figures exactly the same as that varies from browser to browser.** All of the following figures are generated by a primary graphing function from `seaborn`.

# %% [markdown]
# ### Part a
# Use the GSS data you've been working with to replicate the following figure. Answers that input the data directly without constructing it from the GSS dataframe will receive no credit.
#
# <img src="https://raw.githubusercontent.com/jkropko/DS-6001/master/localimages/parta.png" width='700'>
#
# [Hint: the values of occuptational prestige and socioeconomic status are the means of `job_prestige` and `socioeconomic_index` within years of `education`. Note that values of `education` less than 8 are excluded.]
#
# [10 points]

# %%
parta_data = gss_clean[['job_prestige', 'socioeconomic_index', 'education']] \
    .melt(id_vars=['education'], value_vars=['job_prestige', 'socioeconomic_index'], var_name='Index', value_name='value')

parta_data['Index'] = parta_data['Index'].map({'job_prestige':'Occupational Prestige', 'socioeconomic_index':'Socioeconomic Index'})
parta_data = parta_data[parta_data['education']>=8]

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(x='education', y='value', hue='Index',style='Index', data=parta_data, errorbar=None )
plt.xlabel("Years of formal education", fontsize=8)
plt.ylabel("Value", fontsize=8)
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
plt.ylim(0, 80)
plt.title("Occupational Prestige and Socioeconomic Status vs Years of Education", fontsize=8)
# Out:
# Text(0.5, 1.0, 'Occupational Prestige and Socioeconomic Status vs Years of Education')

# %% [markdown]
# ### Part b
# Use the GSS data you've been working with to replicate the following figure. Answers that input the data directly without constructing it from the GSS dataframe will receive no credit.
#
# <img src="https://raw.githubusercontent.com/jkropko/DS-6001/master/localimages/partb_2.png" width='700'>
#
# [Hint: to match the color scheme, you will need to set `center=0`. If the feature names are oriented horizontally instead of vertically, try making the image larger.]
#
# [10 points]

# %%
partb_data = gss_clean[['job_prestige', 'father_job_prestige', 'mother_job_prestige', 'income', 'socioeconomic_index']]
partb_data = partb_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(partb_data, annot=True, center=0)
plt.yticks(rotation=90, fontsize=7)
plt.xticks(rotation=0, fontsize=7)
plt.title("Correlation Between Personal Economic Indicators", fontsize=9)
# Out:
# Text(0.5, 1.0, 'Correlation Between Personal Economic Indicators')

# %% [markdown]
# ### Part c
# Use the GSS data you've been working with to replicate the following figure. Answers that input the data directly without constructing it from the GSS dataframe will receive no credit.
#
# <img src="https://raw.githubusercontent.com/jkropko/DS-6001/master/localdata/partc2.png" width='600'>
#
# [Hint: The individual plots inside the grid have `height=4` and `aspect=1`, and to include the overall title I used
# ```
# g.fig.subplots_adjust(top=.95)
# g.fig.suptitle('Income vs. Prestige by Education', fontsize=16)
# ```
# You will first need to create a version of `education` that collapses values from 0 to 10 to "10 years or fewer" and collapses values from 17 to 20 to "More than 16 years". You can use `.map()`, `.replace()`, or `pd.cut()` to do that.]
#
# [10 points]

# %%
partc_data = gss_clean[['education', 'job_prestige', 'income']]
partc_data['educ_bucket'] = pd.cut(partc_data.education, 
                                bins=[-0.01, 10, 11,12,13,14,15],
                                labels=['10 years or fewer', '12 years', '13 years', '14 years', '15 years', 'More than 16 years'])
# Out:
# /var/folders/fm/2_zxw4w57231pbsnw1dv90yc0000gn/T/ipykernel_74488/4218520909.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partc_data['educ_bucket'] = pd.cut(partc_data.education,

# %%
g = sns.FacetGrid(partc_data, col='educ_bucket', col_wrap=2,
                 height=4, aspect=1)
g.map(sns.regplot, 'job_prestige', 'income')
g.figure.subplots_adjust(top=.95)
g.set_titles('{col_name}')
g.set_axis_labels('Occupational Prestige', 'Income')
g.figure.suptitle('Income vs. Prestige by Education', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Income vs. Prestige by Education')

# %% [markdown]
# ## Problem 4
# In this problem, you will use what you know about data visualization to find and communicate answers to real-world questions.
#
# There is a consistent finding that in the United States that [women get paid only about 83% of what men get paid](https://nwlc.org/issue/equal-pay-and-the-wage-gap/). Other research however finds that the gap is much smaller when comparing [men and women who hold the same job](https://www.politifact.com/factchecks/2018/apr/13/tina-smith/do-women-get-only-80-percent-pay-men-do-same-job/)
#
# ### Part a
# Use the GSS data to investigate the following question: Do men have higher incomes than women?
#
# You may use any kind of data visualization and you may use multiple visualizations to find an answer to this question. In order to receive credit for this problem, you must write in text what parts of your visualizations are important and what we should learn from the visualizations to answer the questions. Please consider the entire distribution of income, not just the means or medians.
#
# [12 points]

# %%
men = gss_clean[gss_clean['sex'] == 'male'][['id', 'income', 'job_prestige', 'weight']]
women = gss_clean[gss_clean['sex'] == 'female'][['id', 'income', 'job_prestige', 'weight']]

# %%
plt.figure(figsize=(7,7))
sns.kdeplot(data=women,x='income', fill=True, label='Women', weights='weight')
sns.kdeplot(data=men,x='income', fill=True, label='Men', weights='weight')
plt.ylabel('Frequency')
plt.xlabel('Income')
plt.xlim(0, 200000)
plt.title('Distribution of Income by Gender (Men/Women only)')
plt.legend()

# %% [markdown]
# <strong>
# This first plot looks at the weighted frequency of men and women with respect to income. Here, we can see that there are more women than men at lower incomes, more men than women at moderate incomes and similar numbers of men and women at high incomes. So, while the small number of women and men making over $130k are equally matched, it does appear that men are making more money than women as a whole. However, this could differ from job to job. It could be related to the jobs that men and women end up in (though this on its own, if true, could support the argument that women's jobs are undervalued there fore they make less).
# </strong>

# %%
parta_data = gss_clean[['income', 'sex', 'job_prestige', 'age']]
parta_data['job_prestige_group'] = pd.DataFrame(pd.cut(parta_data.job_prestige, bins=[-0.1,30, 40, 50, 60, 100], labels=['30 or less', '30-40', '40-50', '50-60', '60 or more']))
# parta_data['income_group'] = pd.cut(parta_data.income, bins=[-0.1, 20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000], labels=['20k or less', '20k-40k', '40k-60k', '60k-80k', '80k-100k', '100k-120k', '120k-140k', '140k or more'])
parta_data_agg = parta_data.groupby(['sex', 'job_prestige_group']).agg(
    job_prestige=('job_prestige', 'median'), 
    income = ('income','median'), 
    count=('income', 'count')
    ).reset_index()
# Out:
# /var/folders/fm/2_zxw4w57231pbsnw1dv90yc0000gn/T/ipykernel_74488/2851755008.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parta_data['job_prestige_group'] = pd.DataFrame(pd.cut(parta_data.job_prestige, bins=[-0.1,30, 40, 50, 60, 100], labels=['30 or less', '30-40', '40-50', '50-60', '60 or more']))
# /var/folders/fm/2_zxw4w57231pbsnw1dv90yc0000gn/T/ipykernel_74488/2851755008.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   parta_data_agg = parta_data.groupby(['sex', 'job_prestige_group']).agg(

# %%
bplot = sns.barplot(x='job_prestige_group', y='income', hue='sex', data=parta_data_agg, errorbar=None)
plt.title("Median Income by Gender and Occupational Prestige Group")
plt.xlabel("Occupational Prestige Score")
plt.ylabel("Median Annual Income")

for rect in bplot.patches:
    xcoor = rect.get_x() + .5*rect.get_width()
    ycoor = rect.get_height()
    plt.text(xcoor, ycoor, str("${:,}".format(round(ycoor))), 
             horizontalalignment='center', 
             verticalalignment='bottom',
             fontsize=6)

# %% [markdown]
# <strong>
# Now, let's look at the data in a different way and see if men and women's median incomes vary within certain jobs. Because we do not have actual occupation data, we are looking at buckets of job prestige and asking the question: do women and men working jobs of similar prestige make similar amoungs of money?
#
# From this plot, we can se that for almost all tiers of jobs, the median income for men is higher than the median income for women.
# </strong>

# %% [markdown]
# ### Part b
# Use the GSS data to investigate the following question: If there is a gender wage gap, is this difference due to the fact that men have jobs with higher occupational prestige than women?
#
# You may use any kind of data visualization and you may use multiple visualizations to find an answer to this question. In order to receive credit for this problem, you must write in text what parts of your visualizations are important and what we should learn from the visualizations to answer the questions. Please consider the entire distributions of income and occupational prestige, not just the means or medians.
#
# [12 points]

# %% [markdown]
# <strong>
# First, I want to see if men do have higher prestige jobs than women.
# </strong>

# %%
print("Mean -- ")
print(f'men: {round(men['job_prestige'].mean(),2)}')
print(f'women: {round(women['job_prestige'].mean(),2)}')

print("Median -- ")
print(f'men: {round(men['job_prestige'].median(),2)}')
print(f'women: {round(women['job_prestige'].median(),2)}')
# Out:
# Mean --
# men: 44.7
# women: 44.67
# Median --
# men: 44.0
# women: 46.0

# %% [markdown]
# <strong>
# Looking at the base means, we can see a slightly differnce in favor of men, but they are very close. The medians show a greater difference, so it may be that while women hold some high prestige positions, they generally have lower prestige.
#
# Let's look deeper.
# </strong>

# %%
plt.figure(figsize=(7,7))
sns.kdeplot(data=women,x='job_prestige', fill=True, label='Women', weights='weight')
sns.kdeplot(data=men,x='job_prestige', fill=True, label='Men', weights='weight')
plt.ylabel('Frequency')
plt.xlabel('Occupational Prestige')
plt.title('Distribution of Occupational Prestige by Gender (Men/Women only)')
plt.legend()

# %% [markdown]
# <strong>
# From this plot, we can see that men are most often in mid-prestige jobs, whereas women are most often at slightly higher prestige jobs. Interestingly, women also seem to have more lower prestige jobs, and at the highest prestige positions, men overtake women again.
#
#
# Now let's look at how this relates to income. First, let's see if income and prestige are correlated for men and women.
# </strong>

# %%
corr_women = women[['income', 'job_prestige']].corr()
corr_men = men[['income', 'job_prestige']].corr()
print(f'women: {round(corr_women,2)}')
print(f'men: {round(corr_men,2)}')
# Out:
# women:               income  job_prestige
# income           1.0           0.3
# job_prestige     0.3           1.0
# men:               income  job_prestige
# income          1.00          0.39
# job_prestige    0.39          1.00

# %% [markdown]
# <strong>
# Income and occupational prestige do appear to be correlated, but it is a weak correlation. Interestingly, that correlation appears to be stronger for men.
#
# None of this appears to support the hypothesis that men make more than women because they hold higher prestige jobs for the following two reasons:
# - it does not appear that on the whole men do hold higher prestige jobs than women. The prestige of jobs they hold are differently
# - it does not appear that there is a strong correlation between job prestige and income.
#
# Lastly, I want to look back at the visual I used for the last question.
# </strong>

# %%
bplot = sns.barplot(x='job_prestige_group', y='income', hue='sex', data=parta_data_agg, errorbar=None)
plt.title("Income by Gender and Occupational Prestige Group")
plt.xlabel("Occupational Prestige Score")
plt.ylabel("Mean Annual Income")

for rect in bplot.patches:
    xcoor = rect.get_x() + .5*rect.get_width()
    ycoor = rect.get_height()
    plt.text(xcoor, ycoor, str("${:,}".format(round(ycoor))), 
             horizontalalignment='center', 
             verticalalignment='bottom',
             fontsize=6)

# %% [markdown]
# <strong>
# In this visual, we can see that even if we look within buckets and only compare men and women's incomes to those in the same bucket, we still see a stark difference in median incomes.
# </strong>

# %% [markdown]
# Note: I realize I used some very similar visuals for the second question as I did for the first (and literally reused one). I explored different types of visuals, including a scatterplot for income/prestige with sex as a huge, a violin plot to show distribution for men and women over income and prestige, and various versions of heat maps to show correlations. However, none of these told the story as well as the ones I originally used, so I stuck with them. Apolgies if this wasn't what was wanted!
